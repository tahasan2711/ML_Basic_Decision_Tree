# %% [markdown]
# # Working with Regression Trees in Python
#
# ## Learning Objectives
# Decision Trees are one of the most popular approaches to supervised machine learning. Decison Trees use an inverted tree-like structure to model the relationship between independent variables and a dependent variable. A tree with a continuous dependent variable is known as a **Regression Tree**. By the end of this tutorial, you will have learned:
#
# + How to import, explore and prepare data
# + How to build a Regression Tree model
# + How to visualize the structure of a Regression Tree
# + How to Prune a Regression Tree

# %% [markdown]
# ## 1. Collect the Data

# %%
import pandas as pd
income = pd.read_csv("income.csv")
#income = pd.get_dummies(income)
income.head()
# Out:
#    Age  Education  Salary
# 0   25  Bachelors    43.9
# 1   30  Bachelors    54.4
# 2   45  Bachelors    62.5
# 3   55  Bachelors    72.5
# 4   65  Bachelors    74.6

# %% [markdown]
# ## 2. Explore the Data

# %%
income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        30 non-null     int64
#  1   Education  30 non-null     object
#  2   Salary     30 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 852.0+ bytes

# %%
income.describe()
# string object is not handled by describe method
# Out:
#              Age      Salary
# count  30.000000   30.000000
# mean   43.366667   64.406667
# std    14.375466   26.202684
# min    24.000000   16.800000
# 25%    30.500000   46.350000
# 50%    45.000000   62.100000
# 75%    55.000000   76.800000
# max    65.000000  118.000000

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns

# %%
ax = sns.boxplot(data = income, x = 'Education', y = 'Salary')

# %%
ax = sns.boxplot(data = income, x = 'Education', y = 'Age')

# %%
ax = sns.scatterplot(data = income, 
                     x = 'Age', 
                     y = 'Salary', 
                     hue = 'Education', 
                     style = 'Education', 
                     s = 150)
ax = plt.legend(bbox_to_anchor = (1.02, 1), loc = 'upper left')

# %% [markdown]
# ## 3. Prepare the Data

# %%
y = income[["Salary"]]

# %%
X = income[["Education","Age"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    train_size = 0.6,
                                                    stratify = X['Education'],
                                                    random_state = 1234)

# %%
X_train.shape, X_test.shape
# Out:
# ((18, 2), (12, 2))

# %%
X_train.head()
# Out:
#        Education  Age
# 0      Bachelors   25
# 16       Masters   45
# 17       Masters   65
# 29  Professional   65
# 8        Diploma   25

# %%
# Numeric code to Education column (whole data set is passed)
X_train = pd.get_dummies(X_train)
X_train.head()
# Out:
#     Age  Education_Bachelors  Education_Diploma  Education_Doctorate  \
# 0    25                 True              False                False
# 16   45                False              False                False
# 17   65                False              False                False
# 29   65                False              False                False
# 8    25                False               True                False
#
#     Education_Masters  Education_Professional
# 0               False                   False
# 16               True                   False
# 17               True                   False
# 29              False                    True
# 8               False                   False

# %%
X_test = pd.get_dummies(X_test)
X_test.head()
# Out:
#     Age  Education_Bachelors  Education_Diploma  Education_Doctorate  \
# 9    30                False               True                False
# 21   25                False              False                False
# 4    65                 True              False                False
# 10   35                False               True                False
# 7    65                False              False                 True
#
#     Education_Masters  Education_Professional
# 9               False                   False
# 21               True                   False
# 4               False                   False
# 10              False                   False
# 7               False                   False

# %% [markdown]
# ## 4. Train and Evaluate the Regression Tree

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 1234)

# %%
model = regressor.fit(X_train,y_train)

# %%
print(model.score(X_train,y_train))
print(model.score(X_test,y_test))
# Out:
# 0.9901253057607573
# 0.5853149222529794

# %%
y_test_pred = model.predict(X_test)

# %%
# MAE
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_test_pred)
# Out:
# np.float64(13.541666666666666)

# %% [markdown]
# ## 5. Visualize the Regression Tree

# %%
from sklearn import tree
plt.figure(figsize = (15,15))
tree.plot_tree(model,
               feature_names=list(X_train.columns),
               filled=True)
# Out:
# [Text(0.48295454545454547, 0.9375, 'Age <= 34.0\nsquared_error = 544.18\nsamples = 18\nvalue = 65.367'),
#  Text(0.18181818181818182, 0.8125, 'Education_Bachelors <= 0.5\nsquared_error = 176.924\nsamples = 5\nvalue = 41.3'),
#  Text(0.33238636363636365, 0.875, 'True  '),
#  Text(0.09090909090909091, 0.6875, 'Age <= 29.0\nsquared_error = 133.402\nsamples = 2\nvalue = 28.35'),
#  Text(0.045454545454545456, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 16.8'),
#  Text(0.13636363636363635, 0.5625, 'squared_error = -0.0\nsamples = 1\nvalue = 39.9'),
#  Text(0.2727272727272727, 0.6875, 'Age <= 27.5\nsquared_error = 19.602\nsamples = 3\nvalue = 49.933'),
#  Text(0.22727272727272727, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 43.9'),
#  Text(0.3181818181818182, 0.5625, 'Age <= 31.0\nsquared_error = 2.102\nsamples = 2\nvalue = 52.95'),
#  Text(0.2727272727272727, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 54.4'),
#  Text(0.36363636363636365, 0.4375, 'squared_error = -0.0\nsamples = 1\nvalue = 51.5'),
#  Text(0.7840909090909091, 0.8125, 'Education_Professional <= 0.5\nsquared_error = 376.98\nsamples = 13\nvalue = 74.623'),
#  Text(0.6335227272727273, 0.875, '  False'),
#  Text(0.6590909090909091, 0.6875, 'Education_Diploma <= 0.5\nsquared_error = 209.287\nsamples = 11\nvalue = 68.773'),
#  Text(0.5454545454545454, 0.5625, 'Age <= 50.0\nsquared_error = 105.837\nsamples = 9\nvalue = 73.489'),
#  Text(0.45454545454545453, 0.4375, 'Education_Doctorate <= 0.5\nsquared_error = 35.541\nsamples = 6\nvalue = 68.383'),
#  Text(0.4090909090909091, 0.3125, 'Age <= 40.0\nsquared_error = 27.712\nsamples = 4\nvalue = 66.925'),
#  Text(0.36363636363636365, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 61.7'),
#  Text(0.45454545454545453, 0.1875, 'Education_Bachelors <= 0.5\nsquared_error = 24.816\nsamples = 3\nvalue = 68.667'),
#  Text(0.4090909090909091, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 74.7'),
#  Text(0.5, 0.0625, 'squared_error = 9.922\nsamples = 2\nvalue = 65.65'),
#  Text(0.5, 0.3125, 'squared_error = 38.44\nsamples = 2\nvalue = 71.3'),
#  Text(0.6363636363636364, 0.4375, 'Education_Doctorate <= 0.5\nsquared_error = 90.027\nsamples = 3\nvalue = 83.7'),
#  Text(0.5909090909090909, 0.3125, 'Age <= 61.0\nsquared_error = 27.04\nsamples = 2\nvalue = 77.7'),
#  Text(0.5454545454545454, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 72.5'),
#  Text(0.6363636363636364, 0.1875, 'squared_error = -0.0\nsamples = 1\nvalue = 82.9'),
#  Text(0.6818181818181818, 0.3125, 'squared_error = -0.0\nsamples = 1\nvalue = 95.7'),
#  Text(0.7727272727272727, 0.5625, 'Age <= 60.0\nsquared_error = 124.322\nsamples = 2\nvalue = 47.55'),
#  Text(0.7272727272727273, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 58.7'),
#  Text(0.8181818181818182, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 36.4'),
#  Text(0.9090909090909091, 0.6875, 'Age <= 55.0\nsquared_error = 75.69\nsamples = 2\nvalue = 106.8'),
#  Text(0.8636363636363636, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 115.5'),
#  Text(0.9545454545454546, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 98.1')]

# %%
importance = model.feature_importances_
#importance_feature_name = model.feature_names_in_
importance
# Out:
# array([0.54597998, 0.06326845, 0.11352129, 0.02490287, 0.        ,
#        0.25232742])

# %%
feature_importance = pd.Series(importance, index = X_train.columns)
feature_importance.sort_values().plot(kind = 'bar')
plt.ylabel('Importance')
# Out:
# Text(0, 0.5, 'Importance')

# %% [markdown]
# ## 6. Prune the Regression Tree

# %%
model.score(X_train,y_train)
# Out:
# 0.9901253057607573

# %%
model.score(X_test,y_test)
# Out:
# 0.5853149222529794

# %% [markdown]
# Let's get the list of effective alphas for the training data.

# %%
path = regressor.cost_complexity_pruning_path(X_train, y_train)
ccp_alphas = path.ccp_alphas
list(ccp_alphas)
# Out:
# [np.float64(0.0),
#  np.float64(0.23361111111110705),
#  np.float64(2.1578395061724223),
#  np.float64(3.004444444444693),
#  np.float64(3.0334259259259144),
#  np.float64(8.409999999999753),
#  np.float64(12.000000000000506),
#  np.float64(13.813611111110644),
#  np.float64(14.822500000000016),
#  np.float64(26.06669753086468),
#  np.float64(31.05601851851865),
#  np.float64(61.1659960718292),
#  np.float64(135.95562548562512),
#  np.float64(222.77094017094078)]

# %% [markdown]
# We remove the maximum effective alpha because it is the trivial tree with just one node.

# %%
ccp_alphas= ccp_alphas[0:-1]
list(ccp_alphas)
# Out:
# [np.float64(0.0),
#  np.float64(0.23361111111110705),
#  np.float64(2.1578395061724223),
#  np.float64(3.004444444444693),
#  np.float64(3.0334259259259144),
#  np.float64(8.409999999999753),
#  np.float64(12.000000000000506),
#  np.float64(13.813611111110644),
#  np.float64(14.822500000000016),
#  np.float64(26.06669753086468),
#  np.float64(31.05601851851865),
#  np.float64(61.1659960718292),
#  np.float64(135.95562548562512)]

# %% [markdown]
# Next, we train several trees using the different values for alpha.

# %%
train_scores, test_scores = [], [] # will be used for model evaluation
for alpha in ccp_alphas:
    regressor_ = DecisionTreeRegressor(random_state = 1234, ccp_alpha = alpha)
    model_ = regressor_.fit(X_train, y_train)
    train_scores.append(model_.score(X_train, y_train))
    test_scores.append(model_.score(X_test, y_test))

# %%
# Plotting scores against alphas to visually detect best alpha
plt.plot(ccp_alphas, 
         train_scores, 
         marker = "o", 
         label = 'train_score', 
         drawstyle = "steps-post")
plt.plot(ccp_alphas, 
         test_scores, 
         marker = "o", 
         label = 'test_score', 
         drawstyle = "steps-post")
plt.legend()
plt.title('R-squared by alpha')
# Out:
# Text(0.5, 1.0, 'R-squared by alpha')

# %%
test_scores
# Out:
# [0.5853149222529794,
#  0.5857107382012932,
#  0.5857107382012932,
#  0.5889110156116097,
#  0.5861012049128272,
#  0.5742699063850475,
#  0.5110187660049715,
#  0.5901546580161237,
#  0.7572572323335666,
#  0.6933555316243081,
#  0.7328980549684876,
#  0.4823659659054369,
#  0.2920328593359385]

# %%
ix = test_scores.index(max(test_scores))
best_alpha = ccp_alphas[ix]
best_alpha
# Out:
# np.float64(14.822500000000016)

# %%
regressor_ = DecisionTreeRegressor(random_state = 1234, ccp_alpha = best_alpha)
model_ = regressor_.fit(X_train, y_train)

# %%
model_.score(X_train, y_train)
# Out:
# 0.8765762758237674

# %%
model_.score(X_test, y_test)
# Out:
# 0.7572572323335666

# %%
plt.figure(figsize = (15,15))
tree.plot_tree(model_, 
                   feature_names = list(X_train.columns),
                   filled = True)
